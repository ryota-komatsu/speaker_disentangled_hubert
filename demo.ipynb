# %% [markdown]
# # Self-Supervised Syllable Discovery Based on Speaker-Disentangled HuBERT

# %%
# Only required for Google Colab
# Runtime -> Change runtime type -> select "T4 GPU" and save
# !git clone https://github.com/ryota-komatsu/speaker_disentangled_hubert
# %cd speaker_disentangled_hubert

# %% [markdown]
# Install dependencies

# %%
# !git clone https://github.com/cheoljun95/sdhubert.git src/sdhubert

# %% [markdown]
# Download LibriSpeech

# %%
# !wget -t 0 -c -P data/LibriSpeech https://www.openslr.org/resources/12/test-clean.tar.gz
# !tar zxvf data/LibriSpeech/test-clean.tar.gz -C data

# %%
import json
import os
import re
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import torchaudio
from IPython.display import Audio, Image

from src.flow_matching import FlowMatchingWithBigVGan
from src.s5hubert import S5HubertForSyllableDiscovery

# %% [markdown]
# Load model

# %%
encoder = S5HubertForSyllableDiscovery.from_pretrained("ryota-komatsu/s5-hubert", device_map="cuda")
decoder = FlowMatchingWithBigVGan.from_pretrained("ryota-komatsu/s5-hubert-decoder-ft", device_map="cuda")

# %% [markdown]
# Load audio

# %%
syllable_alignment_path = "src/sdhubert/files/librispeech_syllable_test.json"
wav_name = "test-clean/61/70968/61-70968-0021.flac"
wav_path = os.path.join("data/LibriSpeech", wav_name)
wav_stem = Path(wav_name).stem

# %%
waveform, sr = torchaudio.load(wav_path)
waveform = torchaudio.functional.resample(waveform, sr, 16000)

# %% [markdown]
# Inference

# %%
outputs = encoder(waveform.cuda())
outputs

# %%
frame_boundary = outputs[0]["durations"].cumsum(0).cpu().numpy()[:-1]
frame_similarity = (outputs[0]["dense"] @ outputs[0]["dense"].T).cpu().numpy()

# %% [markdown]
# Load ground truth syllable alignment

# %%
refs = {}
with open(syllable_alignment_path) as f:
    syllables = json.load(f)
    for item in syllables.values():
        boundary = []
        labels = []
        ticks = []
        for syllable in item["syllables"]:
            start = round(float(syllable["start"]) / 0.02)
            end = round(float(syllable["end"]) / 0.02)

            boundary.append([start, end])
            labels.append(syllable["label"])
            ticks.append((start + end) / 2)
        refs.update(
            {
                item["file_name"]: {
                    "boundary": np.unique(boundary),
                    "labels": labels,
                    "ticks": ticks,
                }
            }
        )

ref_boundary = refs[wav_name]["boundary"]
labels = np.array([re.sub("[0-3]", "", ref) for ref in refs[wav_name]["labels"]])
ticks = refs[wav_name]["ticks"]

# %% [markdown]
# Plot results

# %%
plt.figure()
plt.imshow(frame_similarity)
plt.hlines(ref_boundary, 0, frame_similarity.shape[1] - 1, colors="red", label="ground truth")
# plt.vlines(
#     frame_boundary, 0, frame_similarity.shape[1] - 1, colors="white", linestyles="dotted", label="prediction"
# )
plt.yticks(ticks=ticks, labels=labels, rotation=0, color="black", fontsize=14)
plt.xticks([], [])
# plt.legend()
plt.savefig(f"docs/audio/{wav_stem}.png", bbox_inches="tight")
Image(f"docs/audio/{wav_stem}.png")

# %%
units = outputs[0]["units"].unsqueeze(0)
resynthesized_waveform = decoder(units).waveform.cpu()

# %%
torchaudio.save(f"docs/audio/{wav_stem}.wav", waveform, 16000)
Audio(waveform, rate=sr)

# %%
torchaudio.save(f"docs/audio/{wav_stem}-resynthesis.wav", resynthesized_waveform, 16000)
Audio(resynthesized_waveform, rate=sr)
